# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 三级标题

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend(title = 'gender')

plt.show()

# %%
x = np.array([1,3,5,8])
y = np.array([2,5,9,0])

# %%
plt.plot(x, y, '*-b')

# %%
ypoints = np.array([1,2,5,6,7,9])

# %%
plt.plot(ypoints, '*:', ms = 20)

# %%
plt.plot(ypoints, "o", ms = 10)
plt.show()

# %%
plt.plot(ypoints, ls = ':',lw = 3, marker='o',ms= 8, mec='r', mfc = 'b')

# %% [markdown]
# #### marker表示点的形状， ms表示marker的sizes, mec表示marker 的edge color, mfc表示marker face color
# #### ls表示line style, lw表示line width

# %%
y1 = np.array([1,3,0,7,9])
y2 = np.array([9,7,0,3,1])

# %%
plt.plot(y1, ls='-.')
plt.plot(y2, ls=':')

# %% [markdown]
# ###### 生成指定维度的[0,1)间的随机数

# %%
x = np.random.rand(10)
print(x)
# Out:
# [0.41770449 0.07893649 0.39385334 0.63357971 0.68414664 0.6661206
#  0.64696362 0.34833685 0.26763575 0.38818215]

# %% [markdown]
# ###### 生成的随机数服从正态分布

# %%
x = np.random.randn(4,4)
print(x)
# Out:
# [[ 1.23529477 -1.43169996 -0.35802868 -1.45510097]
#  [-0.40498069  0.44120782 -0.02663876  0.82139118]
#  [-0.01612534  2.75158768  0.87173391  0.78599998]
#  [ 0.40550557 -0.28774291  0.18304957 -0.76974952]]

# %% [markdown]
# ###### np.random.randint(low,high,size=none,dtype=‘I’)：范围为[low,high),dtype默认为int

# %%
x = np.random.randint(-5,5,size = (3,3))
print(x)
# Out:
# [[-3  4  3]
#  [-1  0  2]
#  [-4  1 -3]]

# %%
a = '苹果'
s1 = a.encode(encoding = 'GB2312')
s1
# Out:
# b'\xc6\xbb\xb9\xfb'

# %%
s2 = '西瓜'.encode(encoding = 'GB2312')
s2
# Out:
# b'\xce\xf7\xb9\xcf'

# %%
print(s1 < s2)
# Out:
# True
